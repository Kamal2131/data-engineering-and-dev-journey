# %% [markdown]
# ## Why Data Structures Matter
#
# ### In Data Engineering & Backend Systems, you’ll constantly:
#
# - Transform lists of records
#
# - Remove duplicates (sets)
#
# - Group or map data (dicts)
#
# - Store fixed configs or constants (tuples)
#
# So today’s lesson is not just Python, it’s ETL logic in miniature.

# %% [markdown]
# ## 1. Lists — The Workhorse of Python
# ### Definition:
#
# - A list is an ordered, mutable (changeable) collection of elements.

# %%
lst = [1,2,3,4]
lst
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# You can store any type of element — even mixed ones:

# %%
lst = [1, "kamal", True, 3.14]
lst
# Out:
# [1, 'kamal', True, 3.14]

# %% [markdown]
# #### Indexing & Slicing
#
# - Lists are zero-indexed, meaning the first item is at index 0.

# %%
numbers = [10,20,30,40,50]

print(numbers[0])
print(numbers[-1])
print(numbers[1:4])
# Out:
# 10
# 50
# [20, 30, 40]

# %% [markdown]
# #### Common List Methods
#   Method	            Description	                        Example
# .append(x)	            Adds one item	                numbers.append(50)
#
# .extend(iterable)	    Adds multiple	                numbers.extend([60, 70])
#
# .insert(i, x)	        Insert at position	            numbers.insert(1, 15)
#
# .remove(x)	            Removes first occurrence	    numbers.remove(20)
#
# .pop()	                Removes and returns last item	numbers.pop()
#
# .sort()	                Sorts list	                    numbers.sort()
#
# .reverse()	            Reverses order	                numbers.reverse()

# %%
numbers.append(90)
numbers
# Out:
# [10, 20, 30, 40, 50, 90]

# %%
numbers.extend([60, 70])
numbers
# Out:
# [10, 20, 30, 40, 50, 90, 60, 70]

# %%
numbers.insert(2,120)
numbers
# Out:
# [10, 20, 120, 30, 40, 50, 90, 60, 70]

# %%
numbers.remove(50)
numbers
# Out:
# [10, 20, 120, 30, 40, 90, 70]

# %%
numbers.pop()
numbers
# Out:
# [10, 20, 120, 30, 40, 90]

# %% [markdown]
# #### List Comprehension (Pythonic Shortcut)
# Instead of writing:

# %%
squares = []

for x in [1, 2, 3, 4]:
    squares.append(x ** 2)

squares
# Out:
# [1, 4, 9, 16]

# %% [markdown]
# You can simply write:

# %%
squares = [x**2 for x in [1, 2, 3, 4]]
print(squares)  # [1, 4, 9, 16]
# Out:
# [1, 4, 9, 16]

# %% [markdown]
# ## 2. Tuples — Immutable Lists
# ### Definition:
#
# - A tuple is like a list, but cannot be changed (immutable).

# %%
tup = (1,2,3,4)
print(tup)
# tup.add(20) This is not a valid in tuples

config = ('localhost', 8080)
print(config[0], config[1])  # localhost
# Out:
# (1, 2, 3, 4)
# localhost 8080

# %% [markdown]
# - Use tuples when data must remain constant, like configuration, coordinates, or DB credentials.

# %%
db_config = ('db_user', 'db_pass', 'localhost')
db_config
# Out:
# ('db_user', 'db_pass', 'localhost')

# %% [markdown]
# ## 3. Sets — Unique, Unordered Collections
# ### Definition:
#
# - A set automatically removes duplicates and is optimized for membership testing.

# %%
unique_numbers = {1, 2, 2, 3, 4, 4}
print(unique_numbers)  # 1, 2, 3, 4}
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# ## ⚙️ Set Operations
#
# | Operation       | Example Code                    | Output                |
# |----------------|----------------------------------|-----------------------|
# | Add Element     | `unique_numbers.add(5)`          | `{1, 2, 3, 4, 5}`     |
# | Remove Element  | `unique_numbers.remove(3)`       | `{1, 2, 4, 5}`        |
# | Union           | `{1, 2} \| {2, 3}`               | `{1, 2, 3}`           |
# | Intersection    | `{1, 2} & {2, 3}`                | `{2}`                 |
# | Difference      | `{1, 2} - {2, 3}`                | `{1}`                 |

# %%
unique_numbers.add(3)
unique_numbers.add(5)
print(unique_numbers)


unique_numbers.remove(3)
print(unique_numbers)
# Out:
# {1, 2, 3, 4, 5}
# {1, 2, 4, 5}

# %%
set_a = {1, 2}
set_b = {2, 3}

print(set_a.union(set_b))
print(set_a | set_b)
# Out:
# {1, 2, 3}
# {1, 2, 3}

# %% [markdown]
# #### Use sets when:
#
# - You want to remove duplicates.
#
# - You need to check membership quickly (in is very fast for sets).

# %% [markdown]
# ## 4. Dictionaries — Key-Value Powerhouse
#
# ### Definition:
#
# - A dictionary stores key-value pairs — perfect for representing structured data like JSON.

# %% [markdown]
# ### Concept
#
# - A dictionary (dict) stores data as key → value pairs.
#
# - Keys must be unique and immutable.
#
# - Values can be anything.

# %%
student = {
    "name":"Tuya",
    "age":22,
    "marks":89,
}

student
# Out:
# {'name': 'Tuya', 'age': 22, 'marks': 89}

# %% [markdown]
# ### Access Value

# %%
print(student["name"])
# Out:
# Tuya

# %% [markdown]
# #### Add/Update

# %%
student["status"] = "Active"
student["grade"] = "A+"
student
# Out:
# {'name': 'Tuya', 'age': 22, 'marks': 89, 'grade': 'A+', 'status': 'Active'}

# %% [markdown]
# #### Delete

# %%
del student["status"]
student
# Out:
# {'name': 'Tuya', 'age': 22, 'marks': 89, 'grade': 'A+'}

# %%
students = [
    {'name': 'Tuya', 'age': 17, 'marks': 89, 'grade': 'A+'},
    {'name': 'Kamal', 'age': 22, 'marks': 49, 'grade': 'c'}
]
students
# Out:
# [{'name': 'Tuya', 'age': 17, 'marks': 89, 'grade': 'A+'},
#  {'name': 'Kamal', 'age': 22, 'marks': 49, 'grade': 'c'}]

# %% [markdown]
# #### ⚙️ Looping through Dictionary

# %%
for student in students:
    for key, value in student.items():
        print(f"{key}: {value}")
    print("==============================================")
# Out:
# name: Tuya
# age: 17
# marks: 89
# grade: A+
# ==============================================
# name: Kamal
# age: 22
# marks: 49
# grade: c
# ==============================================

# %% [markdown]
# #### 🧱 Real-World Use
#
# - Represent JSON data from APIs
#
# - Store ETL metadata like schema mappings
#
# - Map keys (IDs) to data

# %% [markdown]
# ## 6. Nested Data Structures
# ### Definition
#
# - You can combine lists, dicts, sets, and tuples to model complex data.

# %%
students = [
    {"name": "Kamal", "marks": 88},
    {"name": "Riya", "marks": 92}
]

# %% [markdown]
# #### Access Nested Data

# %%
# print(students[1]["name"])
# students[0]["name"]

for student in students:
    for key, value in student.items():
        print(f"{key}: {value}")
    print("=============================================")
# Out:
# name: Kamal
# marks: 88
# =============================================
# name: Riya
# marks: 92
# =============================================

# %% [markdown]
# #### 🧱 Real-World Use
#
# - Working with JSON (from APIs or files)
#
# - Representing hierarchical data
#
# - Storing multiple records (like DB rows)

# %% [markdown]
# ##  7. Mini Project — Contact Manager (CLI App)
#
# ### Let’s combine everything you learned 👇
#
# ### 🎯 Goal
#
# #### Build a Contact Manager where you can:
#
# - Add a contact
#
# - View all contacts
#
# - Search by name
#
# - Delete a contact
#
# - Save to JSON file
#
#
# This code is in the Normal_files/ as name `day2_contact_manager.py`
