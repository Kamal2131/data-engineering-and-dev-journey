# %% [markdown]
# ## Day 7 – Git & GitHub Workflow
#
#
# ### Goal:
#
# Learn how to properly manage your code using Git, create clean commits, use branches, and push your work to GitHub daily — essential for any developer or data engineer.

# %% [markdown]
# 🧠 What to Learn Today
# 🔹 1. Basic Git Commands

# %%
# git init  # For Initialize a repository
# git status  # For checking the git repository
# git add .  # For adding to git track for all the files and folder in the repository
# git commit -m "message"  # For Commit that much to track the next change
# git push  # For push the commit to the remote branch
# git pull  # For pulling the repository

# %% [markdown]
# ### 2. Branching Workflow
#
# - Create separate branches for features, fixes, or experiments.

# %% [markdown]
# - git branch dev  => for creating a new branch
# - git checkout dev  => for switching to the specific branch
# - git merge dev  => To merge the branch to main branch

# %% [markdown]
# Use this flow later in your ETL, FastAPI, and Django projects.

# %% [markdown]
# ### 3. GitHub Remote Setup
# - git remote add origin https://github.com/username/reponame.git
# - git push -u origin main

# %% [markdown]
# ### 4. Commit Message Best Practices
#
# #### Great commit messages follow a structure:
#
# - feat: for new features
#
# - fix: for bug fixes
#
# - refactor: for code cleanup
#
# - docs: for documentation
#
# ### Example:
#
# - feat: add CSV reader error handling

# %% [markdown]
# ### 5. README Writing
#
# #### A clean README increases your visibility and credibility.
#
# #### Include:
#
# - Project description
#
# #### Features
#
# - Setup instructions
#
# #### Usage
#
# - Example inputs/outputs
